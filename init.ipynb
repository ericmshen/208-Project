# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting opendp==0.4.0
#   Downloading opendp-0.4.0-py3-none-any.whl (28.0 MB)
# Collecting pymc3==3.11.5
#   Downloading pymc3-3.11.5-py3-none-any.whl (872 kB)
# Collecting patsy>=0.5.1
#   Downloading patsy-0.5.2-py2.py3-none-any.whl (233 kB)
# Collecting fastprogress>=0.2.0
#   Downloading fastprogress-1.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: scipy<1.8.0,>=1.7.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pymc3==3.11.5->-r ./requirements.txt (line 2)) (1.7.3)
# Collecting arviz>=0.11.0
#   Downloading arviz-0.12.1-py3-none-any.whl (1.6 MB)
# Requirement already satisfied: pandas>=0.24.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pymc3==3.11.5->-r ./requirements.txt (line 2)) (1.2.5)
# Requirement already satisfied: dill in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pymc3==3.11.5->-r ./requirements.txt (line 2)) (0.3.4)
# Requirement already satisfied: numpy<1.22.2,>=1.15.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pymc3==3.11.5->-r ./requirements.txt (line 2)) (1.21.6)
# Collecting theano-pymc==1.1.2
#   Downloading Theano-PyMC-1.1.2.tar.gz (1.8 MB)
# Requirement already satisfied: cachetools>=4.2.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pymc3==3.11.5->-r ./requirements.txt (line 2)) (5.0.0)
# Collecting deprecat
#   Downloading deprecat-2.1.1-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pymc3==3.11.5->-r ./requirements.txt (line 2)) (4.2.0)
# Collecting semver>=2.13.0
#   Downloading semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: six in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from patsy>=0.5.1->pymc3==3.11.5->-r ./requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: matplotlib>=3.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from arviz>=0.11.0->pymc3==3.11.5->-r ./requirements.txt (line 2)) (3.5.2)
# Collecting netcdf4
#   Downloading netCDF4-1.5.8-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
# Collecting xarray-einstats>=0.2
#   Downloading xarray_einstats-0.2.2-py3-none-any.whl (33 kB)
# Requirement already satisfied: setuptools>=38.4 in /root/venv/lib/python3.7/site-packages (from arviz>=0.11.0->pymc3==3.11.5->-r ./requirements.txt (line 2)) (47.1.0)
# Collecting xarray>=0.16.1
#   Downloading xarray-0.20.2-py3-none-any.whl (845 kB)
# Requirement already satisfied: packaging in /shared-libs/python3.7/py/lib/python3.7/site-packages (from arviz>=0.11.0->pymc3==3.11.5->-r ./requirements.txt (line 2)) (21.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pandas>=0.24.0->pymc3==3.11.5->-r ./requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas>=0.24.0->pymc3==3.11.5->-r ./requirements.txt (line 2)) (2022.1)
# Requirement already satisfied: filelock in /shared-libs/python3.7/py/lib/python3.7/site-packages (from theano-pymc==1.1.2->pymc3==3.11.5->-r ./requirements.txt (line 2)) (3.6.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from deprecat->pymc3==3.11.5->-r ./requirements.txt (line 2)) (1.14.1)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3==3.11.5->-r ./requirements.txt (line 2)) (4.33.3)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3==3.11.5->-r ./requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3==3.11.5->-r ./requirements.txt (line 2)) (3.0.8)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3==3.11.5->-r ./requirements.txt (line 2)) (9.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3==3.11.5->-r ./requirements.txt (line 2)) (1.4.2)
# Collecting cftime
#   Downloading cftime-1.6.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (229 kB)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from xarray>=0.16.1->arviz>=0.11.0->pymc3==3.11.5->-r ./requirements.txt (line 2)) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->xarray>=0.16.1->arviz>=0.11.0->pymc3==3.11.5->-r ./requirements.txt (line 2)) (3.8.0)
# Building wheels for collected packages: theano-pymc
#   Building wheel for theano-pymc (setup.py): started
#   Building wheel for theano-pymc (setup.py): finished with status 'done'
#   Created wheel for theano-pymc: filename=Theano_PyMC-1.1.2-py3-none-any.whl size=1529946 sha256=3351e7d92c59f7c4d0cd8dee0f4a1fa33e56cbce8dfda35b5f8e0b2792019094
#   Stored in directory: /root/.cache/pip/wheels/f3/af/8c/5dd7553522d74c52a7813806fc7ee1a9caa20a3f7c8fd850d5
# Successfully built theano-pymc
# Installing collected packages: opendp, patsy, fastprogress, cftime, netcdf4, xarray, xarray-einstats, arviz, theano-pymc, deprecat, semver, pymc3
# Successfully installed arviz-0.12.1 cftime-1.6.0 deprecat-2.1.1 fastprogress-1.0.2 netcdf4-1.5.8 opendp-0.4.0 patsy-0.5.2 pymc3-3.11.5 semver-2.13.0 theano-pymc-1.1.2 xarray-0.20.2 xarray-einstats-0.2.2
# WARNING: You are using pip version 20.1.1; however, version 22.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=5d71c9c3-da98-48cf-bf84-cbaf5507821e' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
